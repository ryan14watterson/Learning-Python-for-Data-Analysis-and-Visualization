# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
import webbrowser
website='http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    947  538   403     6  0.571
# 1     2     Green Bay Packers  1,414  787   589    38  0.570
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,448  786   620    42  0.557
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame.Team
# Out:
# 0          Dallas Cowboys
# 1       Green Bay Packers
# 2    New England Patriots
# 3           Chicago Bears
# 4        Baltimore Ravens
# Name: Team, dtype: object

# %%
nfl_frame['First NFL season']
# Out:
# 0    1960
# 1    1921
# 2    1960
# 3    1920
# 4    1996
# Name: First NFL season, dtype: int64

# %%
DataFrame(nfl_frame,columns=['Team','Won','Lost'])
# Out:
#                    Team  Won  Lost
# 0        Dallas Cowboys  538   403
# 1     Green Bay Packers  787   589
# 2  New England Patriots  529   411
# 3         Chicago Bears  786   620
# 4      Baltimore Ravens  233   183

# %%
DataFrame(nfl_frame,columns=['Team','Won','Lost','Stadium'])
# Out:
#                    Team  Won  Lost  Stadium
# 0        Dallas Cowboys  538   403      NaN
# 1     Green Bay Packers  787   589      NaN
# 2  New England Patriots  529   411      NaN
# 3         Chicago Bears  786   620      NaN
# 4      Baltimore Ravens  233   183      NaN

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    947  538   403     6  0.571
# 1     2     Green Bay Packers  1,414  787   589    38  0.570
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,448  786   620    42  0.557
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_frame.head(3)
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    947  538   403     6  0.571
# 1     2     Green Bay Packers  1,414  787   589    38  0.570
# 2     3  New England Patriots    949  529   411     9  0.562
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1960   AFC East

# %%
nfl_frame.tail(3)
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,448  786   620    42  0.557
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_frame.loc[3]
# Out:
# Rank                            4
# Team                Chicago Bears
# GP                          1,448
# Won                           786
# Lost                          620
# Tied                           42
# Pct.                        0.557
# First NFL season             1920
# Division                NFC North
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    947  538   403     6  0.571
# 1     2     Green Bay Packers  1,414  787   589    38  0.570
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,448  786   620    42  0.557
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division         Stadium
# 0              1960   NFC East  Levi's Stadium
# 1              1921  NFC North  Levi's Stadium
# 2              1960   AFC East  Levi's Stadium
# 3              1920  NFC North  Levi's Stadium
# 4              1996  AFC North  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    947  538   403     6  0.571
# 1     2     Green Bay Packers  1,414  787   589    38  0.570
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,448  786   620    42  0.557
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division  Stadium
# 0              1960   NFC East        0
# 1              1921  NFC North        1
# 2              1960   AFC East        2
# 3              1920  NFC North        3
# 4              1996  AFC North        4

# %%
stadiums = Series(["Levi's Stadium","AT&T Stadium"],index=[4,0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    947  538   403     6  0.571
# 1     2     Green Bay Packers  1,414  787   589    38  0.570
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,448  786   620    42  0.557
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division         Stadium
# 0              1960   NFC East    AT&T Stadium
# 1              1921  NFC North             NaN
# 2              1960   AFC East             NaN
# 3              1920  NFC North             NaN
# 4              1996  AFC North  Levi's Stadium

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    947  538   403     6  0.571
# 1     2     Green Bay Packers  1,414  787   589    38  0.570
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,448  786   620    42  0.557
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
data = {'City':['SF','LA','NYC'],'Population':[837000,3880000,8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
website = 'http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True
